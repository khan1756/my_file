# %%
#  question 1 
number_1 =int(input("Enter the first value "));

number_2 =int(input("Enter the first value "));

print("+");
print("-");
print("*");
print("/");
input = input("Enter your operator"); 


addition = (number_1 + number_2);
subtraction = (number_1 - number_2);
multi_plication = (number_1 * number_2);
divisio_n = (number_1 / number_2);

if input == "+":
    print(number_1, "+" ,number_2, "=", addition);

elif input == "-":
    print(number_1, "-" ,number_2, "=", subtraction);

elif input == "*":
    print(number_1, "*" ,number_2, "=", multi_plication);

    
elif input == "/":
    print(number_1, "/" ,number_2, "=", divisio_n);
else:    
   print ("This is an invalid input");
    #  Assigment _question 1 completed 


    # question 2 to check if there is any numeric value in list 
    #   i am trying hard but can't solve it 

    # question 3 
key_value=(input("Enter the key name :"));
value_insert=int(input("Enter the value "));
dict_ionary={}
dict_ionary.update({key_value:value_insert});
print("your values are added successfully");
print(dict_ionary);

# question 4completed 
Dictionary_values = {'Apple':89,'Orange':34,'Strawberry':67,'Mango':74};
print(sum(Dictionary_values.values()));

# question 5 completed 
list_values=[4,2,4,5,2,3,5,7,7,3,9];
list_1=[];
for value in list_values:
    if value not in list_1:
        list_1.append(value);
    else:
        print(value);


        # question 6 completed 
        my_dictionary = {'Apple':89,'Orange':34,'Strawberry':67,'Mango':74};
check_Key= input("Enter the key");
if check_Key in my_dictionary:
  print ("Key already exist");
else:
  print ("Unknown sorry!?");
